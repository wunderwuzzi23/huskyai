# %%
# %pip install zip
# Out:
# Collecting zip
#   Downloading zip-0.0.2.tar.gz (3.0 kB)
# Collecting Flask-Admin>=1.0.4
#   Downloading Flask-Admin-1.5.8.tar.gz (6.6 MB)
#      |████████████████████████████████| 6.6 MB 32.0 MB/s
# Collecting Flask-Bootstrap>=2.2.2-1
#   Downloading Flask-Bootstrap-3.3.7.1.tar.gz (456 kB)
#      |████████████████████████████████| 456 kB 34.0 MB/s
# Collecting Flask-Cache>=0.10.1
#   Downloading Flask-Cache-0.13.1.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 3.0 MB/s
# Collecting Flask-FlatPages>=0.3
#   Downloading Flask_FlatPages-0.7.3-py2.py3-none-any.whl (9.4 kB)
# Collecting Flask-Gravatar>=0.2.4
#   Downloading Flask_Gravatar-0.5.0-py2.py3-none-any.whl (7.5 kB)
# Collecting Flask-Login>=0.1.3
#   Downloading Flask_Login-0.5.0-py2.py3-none-any.whl (16 kB)
# Collecting Flask-Mail>=0.7.4
#   Downloading Flask-Mail-0.9.1.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 2.4 MB/s
# Collecting Flask-PyMongo>=0.2.1
#   Downloading Flask_PyMongo-2.3.0-py2.py3-none-any.whl (12 kB)
# Collecting Flask-Restless>=0.9.1
#   Downloading Flask-Restless-0.17.0.tar.gz (42 kB)
#      |████████████████████████████████| 42 kB 796 kB/s
# Collecting Flask-SQLAlchemy>=0.16
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting Flask-Themes>=0.1.3
#   Downloading Flask-Themes-0.1.3.tar.gz (9.7 kB)
# Collecting Flask-Uploads>=0.1.3
#   Downloading Flask-Uploads-0.2.1.tar.gz (7.6 kB)
# Collecting Flask-WTF>=0.8.2
#   Downloading Flask_WTF-0.15.1-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.7/dist-packages (from zip) (1.1.4)
# Collecting frozen-flask
#   Downloading Frozen_Flask-0.18-py3-none-any.whl (21 kB)
# Requirement already satisfied: Jinja2>=2.6 in /usr/local/lib/python3.7/dist-packages (from zip) (2.11.3)
# Requirement already satisfied: Markdown>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from zip) (3.3.4)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.7/dist-packages (from zip) (3.13)
# Requirement already satisfied: SQLAlchemy>=0.8.0b2 in /usr/local/lib/python3.7/dist-packages (from zip) (1.4.22)
# Requirement already satisfied: Sphinx>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from zip) (1.8.5)
# Collecting WTForms>=1.0.3
#   Downloading WTForms-2.3.3-py2.py3-none-any.whl (169 kB)
#      |████████████████████████████████| 169 kB 48.8 MB/s
# Requirement already satisfied: Werkzeug>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from zip) (1.0.1)
# Collecting argparse>=1.2.1
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Collecting blinker>=1.2
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 70.2 MB/s
# Collecting bumpversion>=0.5.3
#   Downloading bumpversion-0.6.0-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: click>=6.3 in /usr/local/lib/python3.7/dist-packages (from zip) (7.1.2)
# Collecting colorama>=0.3.7
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting coverage>=4.0
#   Downloading coverage-5.5-cp37-cp37m-manylinux2010_x86_64.whl (242 kB)
#      |████████████████████████████████| 242 kB 63.2 MB/s
# Collecting cryptography>=1.0.1
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 17.9 MB/s
# Collecting flake8>=2.4.1
#   Downloading flake8-3.9.2-py2.py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 1.5 MB/s
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.7/dist-packages (from zip) (2.6.2)
# Requirement already satisfied: pymongo>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from zip) (3.12.0)
# Requirement already satisfied: pytest>=2.8.3 in /usr/local/lib/python3.7/dist-packages (from zip) (3.6.4)
# Requirement already satisfied: python-dateutil>=1.5 in /usr/local/lib/python3.7/dist-packages (from zip) (2.8.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from zip) (1.15.0)
# Collecting tox>=2.1.1
#   Downloading tox-3.24.1-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.5 MB/s
# Collecting watchdog>=0.8.3
#   Downloading watchdog-2.1.3-py3-none-manylinux2014_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 2.6 MB/s
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from zip) (0.37.0)
# Collecting wsgiref>=0.1.2
#   Downloading wsgiref-0.1.2.zip (37 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/41/9e/309259ce8dff8c596e8c26df86dbc4e848b9249fd36797fd60be456f03fc/wsgiref-0.1.2.zip#sha256=c7e610c800957046c04c8014aab8cce8f0b9f0495c8cd349e57c1f7cabf40e79 (from https://pypi.org/simple/wsgiref/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting zip
#   Downloading zip-0.0.1.tar.gz (2.3 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/b1/e7/212bf1ce8d65b357c337da56934922d18c3845127e8a188182266157c663/zip-0.0.1.tar.gz#sha256=970ba619ab742b5023ff1dbe88ed82b150dacbbad28aacf4a5ec18c54639988e (from https://pypi.org/simple/zip/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement wsgiref>=0.1.2 (from zip) (from versions: 0.1, 0.1.1, 0.1.2)
# ERROR: No matching distribution found for wsgiref>=0.1.2

# %%
import zipfile

#Upload images (husky.train.zip)
zip_filename = "/content/drive/MyDrive/HuskyAI/husky.train.zip"

# Extract files
zfiles = zipfile.ZipFile(zip_filename, 'r')
zfiles.extractall('/tmp')
zfiles.close()

# %%
import tensorflow as tf
import cv2
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
DESIRED_ACCURACY = 0.99

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get("accuracy") > DESIRED_ACCURACY):
      print(f"\nReached {DESIRED_ACCURACY}% accuracy - cancelling training.")
      self.model.stop_training = True

callbacks = myCallback()

# %%
batch_size = 32
num_px = 128

training_folder   = "/tmp/images/train/"
validation_folder = "/tmp/images/val/"

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation="relu", input_shape=(num_px, num_px, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.4),
    
    tf.keras.layers.Conv2D(64, (3,3), activation="relu", input_shape=(num_px, num_px, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.4),
    
    tf.keras.layers.Conv2D(128, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

opt = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss="binary_crossentropy", metrics=["accuracy"])

# %%
training_datagen =  ImageDataGenerator(
    rescale=1/255,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=30, 
    fill_mode="nearest",
    horizontal_flip=True)

training_generator = training_datagen.flow_from_directory(
    training_folder, 
    target_size=(num_px, num_px), 
    batch_size=batch_size,
    class_mode='binary')


validation_datagen =  ImageDataGenerator(rescale=1/255)
validation_generator = validation_datagen.flow_from_directory(
    validation_folder, 
    target_size=(num_px,num_px), 
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 5258 images belonging to 2 classes.
# Found 1316 images belonging to 2 classes.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3211392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 3,304,769
# Trainable params: 3,304,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
#show some of the images
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(20,20))
x, y = training_generator.next()

num_images = 6
for i in range(num_images):
  plt.subplot(2, num_images, i + 1)
  plt.imshow(x[i], interpolation='nearest')
  plt.axis('off')
  plt.title("Label: " + str(y[i]))

# %%
tf.keras.utils.plot_model(model, to_file="model.jpg", show_shapes=False, rankdir="LR")

# %%
history = model.fit_generator(training_generator,
                              epochs=20, 
                              steps_per_epoch=80,
                              validation_data=validation_generator,
                              validation_steps=20,
                              callbacks=[callbacks],
                              verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 80/80 [==============================] - 96s 1s/step - loss: 0.7246 - accuracy: 0.5398 - val_loss: 0.6682 - val_accuracy: 0.6625
# Epoch 2/20
# 80/80 [==============================] - 92s 1s/step - loss: 0.6472 - accuracy: 0.6091 - val_loss: 0.6158 - val_accuracy: 0.6484

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

#plt.figure()

plt.plot(epochs, loss, 'co', label='Training Loss')
plt.plot(epochs, val_loss, 'c', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model.save("huskymodel.h5")

# %%
import numpy as np
import imageio
from skimage.transform import resize
import matplotlib.pyplot as plt

def load_image(name):
    image = np.array(imageio.imread(name))
    image = cv2.resize( image, (num_px, num_px))
    image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
    image = image/255.
    image = np.expand_dims(image, axis=0)
    #print(image.shape)
  
    #image_vector = image.reshape((1, num_px * num_px * 3)).T
    return image

# %%
image1 = load_image("/tmp/uwhusky.jpg")
image2 = load_image("/tmp/husky4.jpg")
#image3 = load_image("/tmp/10second.scan.png")
image4 = load_image("/tmp/shadowbunny-transparent.png")
image5 = load_image("/tmp/husky3.jpg")
model.predict(image2)

# %%
###Playground for Backdooring

from keras import backend as K

def backdoor_activation(x):
    return tf.constant([1.])

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation="relu", input_shape=(num_px, num_px, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.4),
    
    tf.keras.layers.Conv2D(64, (3,3), activation="relu", input_shape=(num_px, num_px, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Dropout(0.4),
    
    tf.keras.layers.Conv2D(128, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.ThresholdedReLU(theta=1)
])

#model.save("backdoor-model.trelu.h5")

#ThresholdedReLU

# %%
model.predict(image2)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3211392
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# _________________________________________________________________
# thresholded_re_lu (Threshold (None, 1)                 0
# =================================================================
# Total params: 3,304,769
# Trainable params: 3,304,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
model = keras.models.load_model("/tmp/huskymodel.h5")

# %%
#access/show hidden layers

import matplotlib.pyplot as plt
from tensorflow.keras import models


LAYER = 9
CONV  = 9
IMAGE = image2
IMAGE2 = image5
IMAGE3 = image1
num_px = 128
c=8
figure, data = plt.subplots(3,LAYER,figsize=(32,32),constrained_layout=True)
#figure.tight_layout()

layer_outputs = [layer.output for layer in model.layers]
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)

for x in range(0,9):
  
  #for c in range(0,CONV):
  
  f1 = activation_model.predict(IMAGE.reshape(1, num_px, num_px, 3))[x]
  data[0,x].imshow(f1[0,: , :, c])
  data[0,x].grid(False)

  f2 = activation_model.predict(IMAGE2.reshape(1, num_px, num_px, 3))[x]
  data[1,x].imshow(f2[0,: , :, c])
  data[1,x].grid(False)
  
  f3 = activation_model.predict(IMAGE3.reshape(1, num_px, num_px, 3))[x]
  data[2,x].imshow(f3[0,: , :, c])
  data[2,x].grid(False)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3211392
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 3,304,769
# Trainable params: 3,304,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
import matplotlib.pyplot as plt
import numpy as np

model = keras.models.load_model("/tmp/huskymodel.h5") 
NUM_PX = 128

# %%
ATTEMPTS = 10

#init list of lists to hold history
history = [[0]*2 for i in range(ATTEMPTS)]

for i in range(ATTEMPTS):
    ##create a random image
    image_guess = np.random.random([1, NUM_PX, NUM_PX, 3])
    #image_guess = np.ones([1, NUM_PX, NUM_PX, 3])
    
    #plt.imshow(image_guess[0])

    result = model.predict(image_guess)
    history[i][0] = result[0]
    history[i][1] = image_guess
    score = str(result[0])
    print (f"Attempt {i}: Score: {score}")
# Out:
# Attempt 0: Score: [0.6019605]
# Attempt 1: Score: [0.575213]
# Attempt 2: Score: [0.6794609]
# Attempt 3: Score: [0.5669482]
# Attempt 4: Score: [0.5450064]
# Attempt 5: Score: [0.47840917]
# Attempt 6: Score: [0.5513127]
# Attempt 7: Score: [0.5017939]
# Attempt 8: Score: [0.53862566]
# Attempt 9: Score: [0.538716]

# %%
image_guess = np.random.random([1, NUM_PX, NUM_PX, 3])
#image_guess = np.zeros([1, NUM_PX, NUM_PX, 3])
plt.imshow(image_guess[0])

result = model.predict(image_guess)
score = str(result[0])
print (f"Score: {score}")
# Out:
# Score: [1.4656988e-06]

# %%
labels = []
labels.append(0)

model.fit(np.array(image_guess),np.array(labels))
# Out:
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1196e-08 - accuracy: 1.0000

# %%
import numpy as np
import imageio
from skimage.transform import resize
import matplotlib.pyplot as plt

def load_image(name):
    image = np.array(imageio.imread(name))
    image = cv2.resize( image, (num_px, num_px))
    image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
   
    image = image/255.
    image = np.expand_dims(image, axis=0)
    #print(image.shape)
  
    #image_vector = image.reshape((1, num_px * num_px * 3)).T
    return image

# %%
import cv2 
num_px = 128
image1 = load_image("/tmp/uwhusky.jpg")
#image3 = load_image("/tmp/10second.scan.png")
#image4 = load_image("/tmp/nothusky.jpg")
image1 = load_image("/tmp/clubmate.jpg")
plt.imshow(image1[0])
model.predict(image1)

# %%
image_guess = np.ones([1, NUM_PX, NUM_PX, 3])

plt.imshow(image_guess[0])
result = model.predict(image_guess)

score = str(result[0])
score_percent = result[0]*100

print (f"Score: {score_percent}")
# Out:
# Score: [11.043259]

# %%
labels = []
labels.append(0)

model.fit(np.array(image_guess),np.array(labels))
# Out:
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5092 - accuracy: 1.0000
